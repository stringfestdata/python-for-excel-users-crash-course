# %% [markdown]
# 1. Import from the Standard Library
# 2. Confirm packages available to you
# 3. Import and alias `pandas`

# %%
abs(-10)

# %%
sqrt(25)

# %%
# Standard library...
import math

sqrt(25)

# %%
math.sqrt(25)

# %%
# What's all available to me?
# !pip list

# %%
import pandas

pandas.__version__

# %%
import pandas as pd

pd.__version__
